# %% [markdown]
# ### if문

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
if True:
    print('실핼문장 실행')
# Out:
# 실핼문장 실행

# %%
# if문에서 조건식이 False였을때는 아무것도 실행하지 않고 끝이 난다.
if False:
    print('실핼문장 실행')

# %% [markdown]
# #### 들여쓰기의 중요성

# %%
if True:
    print('실행문장 실행')
print('if문 밖에 있는 실핼문장')
# Out:
# 실행문장 실행
# if문 밖에 있는 실핼문장

# %%
# if문 밖에 있는 들여쓰기를 벗어난 실행문장만 False 조건에 영향을 받지 않고 실행이 된다.
if False:
    print('실행문장 실행')
print('if문 밖에 있는 실핼문장')
# Out:
# if문 밖에 있는 실핼문장

# %%
money = 20000
if money >= 10000:
    print('택시를 타고 편하게 집에 간다.')
# Out:
# 택시를 타고 편하게 집에 간다.

# %% [markdown]
# ### if - else문
# - 들여쓰기 주의 !!

# %%
# 조건문 if - else를 활용해서 money가 만원 이상이면 '택시', 만원 이하면 '버스'를 탄다는 출력문 작성
if money >= 10000:
    print('택시 탑승')
else:
    print('버스 탑승')
# Out:
# 택시 탑승

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = int(input('정수 입력 >> '))

# if num%15==0:
if num%3==0 and num%5==0:
    print(f'정수 {num}은(는) 3과 5의 배수입니다.')
else:
    print(f' 정수 {num}은(는) 3과 5의 배수가 아닙니다.')
# Out:
# 정수 입력 >> 15
# 정수 15은(는) 3과 5의 배수입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cnt_mask = int(input('마스크 개수 입력 >> '))

pack8, pack5, temp = 0, 0, 0

if cnt_mask >= 8:
    pack8 = cnt_mask // 8
    pack5 = cnt_mask % 8 // 5
    temp = cnt_mask % 8 % 5
else:
    pack5 = cnt_mask % 8 // 5
    temp = cnt_mask % 8 % 5
if temp > 0:
    pack5 += 1
    
print('8개들이 포장지 개수 : ', pack8)
print('5개들이 포장지 개수 : ', pack5)
# Out:
# 마스크 개수 입력 >> 7
# 8개들이 포장지 개수 :  0
# 5개들이 포장지 개수 :  2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1 = int(input('첫 번째 정수 입력 >> '))
num2 = int(input('두 번째 정수 입력 >> '))

if num1 > num2:
    print('첫 번째 정수가 더 큽니다.')
elif num1 == num2:
    print('두 수가 똑같습니다.')
else:
    print('두 번째 정수가 더 큽니다.')
# Out:
# 첫 번째 정수 입력 >> 4
# 두 번째 정수 입력 >> 4
# 두 수가 똑같습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
score = int(input('점수 입력 >> '))

grade = ''

if 100 >= score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'B'
elif score >= 70:
    grade = 'C'
elif score >= 60:
    grade = 'D'
elif score < 60:
    grade = 'F'
else:
    print('잘못된 점수입니다.')
    
print(f'{score}점은 {grade}학점 입니다.')
# Out:
# 점수 입력 >> 98
# 98점은 A학점 입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("""
================================================
================---- 자판기 ----================
================================================
== 1.콜라 == 2.사이다 ==  3.물  =======insert===
==--------==----------==--------=======------===
==   600  ==    800   ==  1000  ======= 000원===
=======================================------===
================================================
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==+++++++++++++++              +++++++++++++++==
==+++++++++++++++     SMHRD    +++++++++++++++==
==+++++++++++++++              +++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
================================================
================================================
  ===                                      ===
  ===                                      ===""")

coin = int(input('금액 넣기 >> '))
menu = int(input('메뉴 선택(번호 입력) >> '))

if menu == 1 and coin >= 600:
    money = coin - 600
    print(f'1000원 : {money // 1000}개, 500원 {money % 1000 // 500}개, 100원 {money % 1000 % 500 // 100}개')
elif menu == 2 and coin >= 800:
    money = coin - 800
    print(f'1000원 : {money // 1000}개, 500원 {money % 1000 // 500}개, 100원 {money % 1000 % 500 // 100}개')
elif menu == 3 and coin >= 1000:
    money = coin - 1000
    print(f'1000원 : {money // 1000}개, 500원 {money % 1000 // 500}개, 100원 {money % 1000 % 500 // 100}개')
else:
    print('금액이 부족합니다.')
# Out:
# ...
# ================---- 자판기 ----================
# ...
# == 1.콜라 == 2.사이다 ==  3.물  =======insert===
# ==--------==----------==--------=======------===
# ==   600  ==    800   ==  1000  ======= 000원===
# =======================================------===
# ...
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==+++++++++++++++              +++++++++++++++==
# ==+++++++++++++++     SMHRD    +++++++++++++++==
# ==+++++++++++++++              +++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ...
#   ===                                      ===
#   ===                                      ===
# 금액 넣기 >> 2000
# 메뉴 선택(번호 입력) >> 1
# 1000원 : 1개, 500원 0개, 100원 4개
